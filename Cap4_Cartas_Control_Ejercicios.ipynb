# %% [markdown]
# #EJERCICIOS CARTAS DE CONTROL PARA VARIABLES Y ATRIBUTOS

# %% [markdown]
# #EJERCICIOS DE CARTAS PARA VARIABLES

# %% [markdown]
# ##Ejercicio 1: Carta X-barra

# %%
duracion = [
    [4.5, 3.2, 5.1, 6.7, 2.9, 4.8, 3.6, 5.5, 4.2, 6.1, 3.8, 5.2, 4.9, 6.4, 3.4, 5.7, 4.1, 6.3, 3.9, 5.3],
    [3.7, 5.6, 4.3, 6.2, 3.5, 5.8, 4.6, 6.5, 3.3, 5.9, 4.7, 6.6, 3.1, 5.4, 4.4, 6.8, 2.8, 4.0, 3.0, 5.0],
    [4.8, 6.2, 3.4, 5.7, 4.1, 6.3, 3.9, 5.3, 4.9, 6.4, 3.6, 5.5, 4.2, 6.1, 3.8, 5.2, 4.7, 6.6, 3.3, 5.9],
    [3.2, 5.1, 6.7, 2.9, 4.5, 3.6, 5.8, 4.6, 6.5, 3.0, 5.0, 4.0, 6.8, 2.8, 3.7, 5.6, 4.3, 6.4, 3.4, 5.7],
    [5.4, 4.4, 6.8, 2.8, 4.0, 3.0, 5.0, 4.1, 6.3, 3.9, 5.3, 4.2, 6.1, 3.8, 5.2, 4.7, 6.6, 3.3, 5.9, 4.6],
    [6.2, 3.4, 5.7, 4.1, 6.3, 3.9, 5.3, 4.9, 6.4, 3.6, 5.5, 4.2, 6.1, 3.8, 5.2, 4.5, 3.2, 5.1, 6.7, 2.9],
    [5.8, 4.6, 6.5, 3.3, 5.9, 4.7, 6.6, 3.1, 5.4, 4.4, 6.8, 2.8, 4.0, 3.0, 5.0, 4.1, 6.2, 3.5, 5.8, 4.3]
]
print(duracion)

# %% [markdown]
# ##Ejercicio 2: Carta R

# %%
tiempo = [
    [12, 18, 22, 25, 15, 20, 28, 14, 19, 21],
    [17, 23, 26, 13, 16, 24, 27, 11, 29, 30],
    [14, 19, 21, 12, 18, 22, 25, 15, 20, 28],
    [13, 16, 24, 27, 11, 29, 30, 17, 23, 26],
    [12, 18, 22, 25, 15, 20, 28, 14, 19, 21],
    [13, 16, 24, 27, 11, 29, 30, 17, 23, 26],
    [14, 19, 21, 12, 18, 22, 25, 15, 20, 28],
    [17, 23, 26, 13, 16, 24, 27, 11, 29, 30],
    [12, 18, 22, 25, 15, 20, 28, 14, 19, 21],
    [17, 23, 26, 13, 16, 24, 27, 11, 29, 30]
]
print(tiempo)

# %% [markdown]
# ##Ejercicio 3: Carta S

# %%
tiempo = [
    [22, 41, 15, 30, 12, 55, 28, 18, 37, 48, 10, 25, 36, 50, 19, 33, 43, 52, 20, 45, 14, 38, 26, 57, 31],
    [16, 32, 42, 49, 23, 56, 17, 11, 29, 54, 13, 39, 46, 21, 34, 44, 58, 27, 53, 40, 24, 47, 35, 51, 59],
    [30, 45, 18, 39, 10, 54, 25, 22, 48, 57, 12, 34, 43, 20, 32, 51, 58, 19, 52, 14, 38, 28, 53, 36, 60],
    [21, 46, 13, 35, 11, 50, 27, 17, 41, 56, 15, 33, 49, 23, 37, 44, 55, 16, 53, 19, 40, 29, 58, 31, 47],
    [14, 38, 19, 32, 12, 47, 26, 15, 42, 59, 13, 30, 55, 22, 33, 48, 56, 20, 51, 17, 36, 25, 57, 40, 54],
    [17, 41, 20, 33, 11, 49, 29, 16, 43, 60, 14, 31, 53, 24, 36, 50, 57, 21, 52, 18, 39, 28, 58, 44, 55]
]
print(tiempo)

# %% [markdown]
# ##Ejercicio 4: Carta X-S

# %%
calidad = [
    [8, 6, 7, 9, 5, 4, 8, 7, 6, 8],
    [9, 7, 6, 8, 5, 6, 9, 7, 8, 6],
    [7, 6, 8, 9, 5, 4, 8, 6, 7, 8],
    [8, 7, 6, 9, 4, 5, 9, 8, 6, 7],
    [6, 5, 8, 7, 4, 6, 7, 8, 6, 5],
    [7, 6, 8, 9, 5, 4, 8, 6, 7, 8],
    [8, 7, 6, 9, 5, 6, 9, 7, 8, 6],
    [7, 6, 8, 9, 4, 5, 9, 8, 6, 7],
    [6, 5, 8, 7, 4, 6, 7, 8, 6, 5],
    [8, 6, 7, 9, 5, 4, 8, 7, 6, 8],
    [9, 7, 6, 8, 5, 6, 9, 7, 8, 6],
    [7, 6, 8, 9, 5, 4, 8, 6, 7, 8],
    [8, 7, 6, 9, 4, 5, 9, 8, 6, 7],
    [6, 5, 8, 7, 4, 6, 7, 8, 6, 5],
    [7, 6, 8, 9, 5, 4, 8, 6, 7, 8],
    [8, 7, 6, 9, 5, 6, 9, 7, 8, 6],
    [7, 6, 8, 9, 4, 5, 9, 8, 6, 7],
    [6, 5, 8, 7, 4, 6, 7, 8, 6, 5],
    [8, 6, 7, 9, 5, 4, 8, 7, 6, 8],
    [9, 7, 6, 8, 5, 6, 9, 7, 8, 6]
]
print(calidad)

# %% [markdown]
# #EJERCICIOS DE CARTAS PARA ATRIBUTOS

# %% [markdown]
# ##Ejercicio 1: Carta P

# %%
satisfechos = [25, 33, 42, 17, 28, 10, 48, 39, 16, 30,
               43, 15, 27, 34, 11, 44, 20, 38, 49, 18,
               32, 46, 13, 35, 21, 45, 31, 19, 29, 47,
               14, 41, 22, 50, 36, 12, 40, 26, 37, 23,
               24, 10, 50, 10, 42, 10, 50, 11, 39, 43
               ]
print(satisfechos)

# %% [markdown]
# ##Ejercicio 2: Carta np

# %%
satisfechos = [30, 41, 36, 12, 22, 34, 15, 10, 49, 47,
               27, 43, 25, 19, 46, 16, 13, 14, 50, 39,
               29, 11, 44, 18, 35, 48, 42, 23, 17, 40,
               37, 26, 21, 32, 20, 33, 45, 38, 24, 28,
               10, 31, 50, 10, 10, 10, 10, 10, 50, 10
               ]
print(satisfechos)

# %% [markdown]
# ##Ejercicio 3: Carta C

# %%
quejas = [12, 28, 35, 50, 15, 41, 10, 48, 14, 49,
          37, 21, 11, 46, 19, 36, 25, 30, 18, 43,
          44, 24, 10, 32, 13, 38, 23, 47, 29, 17,
          45, 31, 20, 42, 10, 26, 10, 33, 10, 10,
          10, 39, 34, 10, 10, 27, 10, 16, 40, 22
          ]
print(quejas)

# %% [markdown]
# ##Ejercicio Extra Cartas

# %%
muestras =
 [[4.5,
  3.2,
  5.1,
  6.7,
  2.9,
  4.8,
  3.6,
  5.5,
  4.2,
  6.1,
  3.8,
  5.2,
  4.9,
  6.4,
  3.4,
  5.7,
  4.1,
  6.3,
  3.9,
  5.3],
 [3.7,
  5.6,
  4.3,
  6.2,
  3.5,
  5.8,
  4.6,
  6.5,
  3.3,
  5.9,
  4.7,
  6.6,
  3.1,
  5.4,
  4.4,
  6.8,
  2.8,
  4.0,
  3.0,
  5.0],
 [4.8,
  6.2,
  3.4,
  5.7,
  4.1,
  6.3,
  3.9,
  5.3,
  4.9,
  6.4,
  3.6,
  5.5,
  4.2,
  6.1,
  3.8,
  5.2,
  4.7,
  6.6,
  3.3,
  5.9],
 [3.2,
  5.1,
  6.7,
  2.9,
  4.5,
  3.6,
  5.8,
  4.6,
  6.5,
  3.0,
  5.0,
  4.0,
  6.8,
  2.8,
  3.7,
  5.6,
  4.3,
  6.4,
  3.4,
  5.7],
 [5.4,
  4.4,
  6.8,
  2.8,
  4.0,
  3.0,
  5.0,
  4.1,
  6.3,
  3.9,
  5.3,
  4.2,
  6.1,
  3.8,
  5.2,
  4.7,
  6.6,
  3.3,
  5.9,
  4.6],
 [6.2,
  3.4,
  5.7,
  4.1,
  6.3,
  3.9,
  5.3,
  4.9,
  6.4,
  3.6,
  5.5,
  4.2,
  6.1,
  3.8,
  5.2,
  4.5,
  3.2,
  5.1,
  6.7,
  2.9],
 [5.8,
  4.6,
  6.5,
  3.3,
  5.9,
  4.7,
  6.6,
  3.1,
  5.4,
  4.4,
  6.8,
  2.8,
  4.0,
  3.0,
  5.0,
  4.1,
  6.2,
  3.5,
  5.8,
  4.3]]

  print(muestras)
